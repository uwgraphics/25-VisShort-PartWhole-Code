# %% [markdown]
# # Modelling the effects of distToHalfQuarter, anchoring and rounding in the task performance of estimation in part-to-whole charts

# %%
library(ggplot2)
library(dplyr)
library(ggdist)
library(lme4)
library(ggeffects)
library(patchwork)
library(lmerTest)
library(brms)
library(blme)

# %%
# Load data
lineData <- read.csv("data/alignmentDistsStudy7Line.csv", header=T)
pieData <- read.csv("data/alignmentDistsStudy7Pie.csv", header=T)
lineData$chartType <- "line"
pieData$chartType <- "pie"

lineData$alignment <- factor(lineData$alignment, levels = c("aligned", "non-aligned"))

lineData <- lineData %>%
  mutate(alignmentCategory = case_when(
    distToHorizontalVertical == 0 ~ "aligned",
    distToHorizontalVertical >= 1 & distToHorizontalVertical <= 4 ~ "near-aligned",
    distToHorizontalVertical >= 5 ~ "far"
  ))

pieData <- pieData %>%
  mutate(alignmentCategory = case_when(
    distToHorizontalVertical == 0 ~ "aligned",
    distToHorizontalVertical >= 1 & distToHorizontalVertical <= 4 ~ "near-aligned",
    distToHorizontalVertical >= 5 ~ "far"
  ))

lineData <- lineData %>%
  mutate(
    anchor = ifelse(distToHalfQuarter == 0, "anchor", "non-anchor"),
    anchorCategory = case_when(
      distToHalfQuarter == 0 ~ "anchor",
      distToHalfQuarter >= 1 & distToHalfQuarter <= 4 ~ "near-anchor",
      distToHalfQuarter >= 5 ~ "far"
    ),
    anchor = factor(anchor, levels = c("anchor", "non-anchor")),
    anchorCategory = factor(anchorCategory, levels = c("anchor", "near-anchor", "far"))
  )

pieData <- pieData %>%
  mutate(
    anchor = ifelse(distToHalfQuarter == 0, "anchor", "non-anchor"),
    anchorCategory = case_when(
      distToHalfQuarter == 0 ~ "anchor",
      distToHalfQuarter >= 1 & distToHalfQuarter <= 4 ~ "near-anchor",
      distToHalfQuarter >= 5 ~ "far"
    ),
    anchor = factor(anchor, levels = c("anchor", "non-anchor")),
    anchorCategory = factor(anchorCategory, levels = c("anchor", "near-anchor", "far"))
  )

lineData <- lineData %>%
  mutate(
    anchorType = case_when(
      distToHalfQuarter == 0 & correctResponse == 25 ~ "25",
      distToHalfQuarter == 0 & correctResponse == 50 ~ "50",
      distToHalfQuarter == 0 & correctResponse == 75 ~ "75",
      TRUE ~ "non-anchor"
    ),
    anchorType = factor(anchorType, levels = c("25", "50", "75", "non-anchor"))
  )

pieData <- pieData %>%
  mutate(
    anchorType = case_when(
      distToHalfQuarter == 0 & correctResponse == 25 ~ "25",
      distToHalfQuarter == 0 & correctResponse == 50 ~ "50",
      distToHalfQuarter == 0 & correctResponse == 75 ~ "75",
      TRUE ~ "non-anchor"
    ),
    anchorType = factor(anchorType, levels = c("25", "50", "75", "non-anchor"))
  )

lineData$alignmentCategory <- factor(lineData$alignmentCategory, levels = c("aligned", "near-aligned", "far"))
pieData$alignmentCategory <- factor(pieData$alignmentCategory, levels = c("aligned", "near-aligned", "far"))

lineData$distToNearest5 <- abs(lineData$correctResponse - round(lineData$correctResponse / 5) * 5)
lineData$D5_factor <- factor(lineData$distToNearest5)
lineData$distToNearest10 <- abs(lineData$correctResponse - round(lineData$correctResponse / 10) * 10)

pieData$distToNearest5 <- abs(pieData$correctResponse - round(pieData$correctResponse / 5) * 5)
pieData$D5_factor <- factor(pieData$distToNearest5)
pieData$distToNearest10 <- abs(pieData$correctResponse - round(pieData$correctResponse / 10) * 10)

pieData$userID <- pieData$userID + max(lineData$userID) + 1  # e.g., if lineData has IDs 0–39, pieData gets 40–79
data <- rbind(lineData, pieData)

# %%
lineModel <- lmer(
  absDiff ~ alignment + anchor + distToNearest5 + alignment:anchor + (1 + alignment + anchor + distToNearest5 | userID),
  data = lineData
)
summary(lineModel)
# Out:
# boundary (singular) fit: see help('isSingular')
#
# Warning message:
# “Model failed to converge with 1 negative eigenvalue: -3.0e+01”
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: absDiff ~ alignment + anchor + distToNearest5 + alignment:anchor +
#     (1 + alignment + anchor + distToNearest5 | userID)
#    Data: lineData
#
# REML criterion at convergence: 15698.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.6019 -0.4663 -0.1371  0.2388 16.7259
#
# Random effects:
#  Groups   Name                 Variance Std.Dev. Corr
#  userID   (Intercept)          0.3651   0.6042
#           alignmentnon-aligned 0.4190   0.6473   -1.00
#           anchornon-anchor     0.6459   0.8037   -0.78  0.78
#           distToNearest5       0.1976   0.4445   -0.27  0.27 -0.39
#  Residual                      7.6897   2.7730
# Number of obs: 3200, groups:  userID, 40
#
# Fixed effects:
#                                         Estimate Std. Error         df t value
# (Intercept)                             -0.01252    0.31237  285.95630  -0.040
# alignmentnon-aligned                     1.27173    0.45194 2024.42960   2.814
# anchornon-anchor                         1.25036    0.34235  246.60528   3.652
# distToNearest5                           0.09581    0.09952   39.05371   0.963
# alignmentnon-aligned:anchornon-anchor    0.13048    0.45159 3116.75267   0.289
#                                       Pr(>|t|)
# (Intercept)                           0.968051
# alignmentnon-aligned                  0.004941 **
# anchornon-anchor                      0.000317 ***
# distToNearest5                        0.341602
# alignmentnon-aligned:anchornon-anchor 0.772643
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) algnm- anchr- dstTN5
# algnmntnn-l -0.696
# anchrnn-nch -0.916  0.637
# distToNrst5 -0.058  0.043 -0.286
# algnmntn-:-  0.627 -0.949 -0.602 -0.002
# optimizer (nloptwrap) convergence code: 0 (OK)
# boundary (singular) fit: see help('isSingular')

# %%
m_anchoring <- lmer(
  absDiff ~ alignment * anchor + (1 | userID),
  data = subset(lineData, distToNearest5 == 0)
)
summary(m_anchoring)
# Out:
# boundary (singular) fit: see help('isSingular')
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: absDiff ~ alignment * anchor + (1 | userID)
#    Data: subset(lineData, distToNearest5 == 0)
#
# REML criterion at convergence: 3413.2
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -0.8536 -0.3785 -0.0917  0.1951 12.9134
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  userID   (Intercept)  0.00    0.000
#  Residual             12.16    3.487
# Number of obs: 640, groups:  userID, 40
#
# Fixed effects:
#                                        Estimate Std. Error        df t value
# (Intercept)                           2.809e-16  3.738e-01 6.360e+02   0.000
# alignmentnon-aligned                  1.260e+00  5.534e-01 6.360e+02   2.277
# anchornon-anchor                      1.320e+00  4.300e-01 6.360e+02   3.069
# alignmentnon-aligned:anchornon-anchor 3.963e-01  6.396e-01 6.360e+02   0.620
#                                       Pr(>|t|)
# (Intercept)                            1.00000
# alignmentnon-aligned                   0.02310 *
# anchornon-anchor                       0.00224 **
# alignmentnon-aligned:anchornon-anchor  0.53570
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) algnm- anchr-
# algnmntnn-l -0.675
# anchrnn-nch -0.869  0.587
# algnmntn-:-  0.584 -0.865 -0.672
# optimizer (nloptwrap) convergence code: 0 (OK)
# boundary (singular) fit: see help('isSingular')

# %%
levels(lineData$D5_factor)
# Out:
# [1] "0" "1" "2"

# %%
m_full <- lmer(
  absDiff ~ alignment * anchor * D5_factor + (1 | userID),
  data = lineData
)
summary(m_full)
# Out:
# fixed-effect model matrix is rank deficient so dropping 4 columns / coefficients
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: absDiff ~ alignment * anchor * D5_factor + (1 | userID)
#    Data: lineData
#
# REML criterion at convergence: 15749.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.2781 -0.4686 -0.1705  0.1929 16.7037
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  userID   (Intercept) 0.1687   0.4107
#  Residual             7.9236   2.8149
# Number of obs: 3200, groups:  userID, 40
#
# Fixed effects:
#                                         Estimate Std. Error         df t value
# (Intercept)                            5.104e-03  3.088e-01  2.491e+03   0.017
# alignmentnon-aligned                   1.249e+00  4.470e-01  3.157e+03   2.794
# anchornon-anchor                       1.322e+00  3.473e-01  3.155e+03   3.807
# D5_factor1                            -2.407e-02  2.038e-01  3.154e+03  -0.118
# D5_factor2                             9.807e-02  2.030e-01  3.154e+03   0.483
# alignmentnon-aligned:anchornon-anchor  3.905e-01  5.167e-01  3.157e+03   0.756
# alignmentnon-aligned:D5_factor1       -4.598e-01  3.031e-01  3.156e+03  -1.517
# alignmentnon-aligned:D5_factor2       -7.906e-02  3.032e-01  3.156e+03  -0.261
#                                       Pr(>|t|)
# (Intercept)                           0.986813
# alignmentnon-aligned                  0.005236 **
# anchornon-anchor                      0.000143 ***
# D5_factor1                            0.905978
# D5_factor2                            0.629126
# alignmentnon-aligned:anchornon-anchor 0.449844
# alignmentnon-aligned:D5_factor1       0.129392
# alignmentnon-aligned:D5_factor2       0.794283
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) algnm- anchr- D5_fc1 D5_fc2 alg-:- a-:D5_1
# algnmntnn-l -0.661
# anchrnn-nch -0.850  0.587
# D5_factor1   0.000  0.000 -0.416
# D5_factor2   0.000  0.000 -0.418  0.712
# algnmntn-:-  0.572 -0.865 -0.673  0.280  0.281
# algnm-:D5_1  0.000  0.000  0.280 -0.673 -0.479 -0.428
# algnm-:D5_2  0.000  0.000  0.280 -0.477 -0.670 -0.428  0.730
# fit warnings:
# fixed-effect model matrix is rank deficient so dropping 4 columns / coefficients

# %%
model_interact <- lmer(
  absDiff ~ alignment * distToHalfQuarter + (1 | userID),
  data = lineData
)
summary(model_interact)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: absDiff ~ alignment * distToHalfQuarter + (1 | userID)
#    Data: lineData
#
# REML criterion at convergence: 15717.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.4404 -0.4500 -0.1556  0.1967 16.9136
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  userID   (Intercept) 0.1756   0.4191
#  Residual             7.8191   2.7963
# Number of obs: 3200, groups:  userID, 40
#
# Fixed effects:
#                                         Estimate Std. Error        df t value
# (Intercept)                            4.519e-01  1.536e-01 4.326e+02   2.942
# alignmentnon-aligned                   1.281e+00  1.960e-01 3.157e+03   6.536
# distToHalfQuarter                      1.286e-01  1.862e-02 3.157e+03   6.906
# alignmentnon-aligned:distToHalfQuarter 1.059e-02  2.633e-02 3.157e+03   0.402
#                                        Pr(>|t|)
# (Intercept)                             0.00343 **
# alignmentnon-aligned                   7.36e-11 ***
# distToHalfQuarter                      6.01e-12 ***
# alignmentnon-aligned:distToHalfQuarter  0.68756
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) algnm- dstTHQ
# algnmntnn-l -0.638
# dstTHlfQrtr -0.779  0.611
# algnmn-:THQ  0.551 -0.863 -0.707

# %%
model <- lmer(
    absDiff ~ chartType * (a + distToHorizontalVertical + distToNearest5) + (1 + distToHalfQuarter + distToHorizontalVertical + distToNearest5 | userID),
    data = data
)
summary(model)
# Out:
# boundary (singular) fit: see help('isSingular')
#
# Warning message:
# “Model failed to converge with 1 negative eigenvalue: -5.4e+02”
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: absDiff ~ chartType * (distToHalfQuarter + distToHorizontalVertical +
#     distToNearest5) + (1 + distToHalfQuarter + distToHorizontalVertical +
#     distToNearest5 | userID)
#    Data: data
#
# REML criterion at convergence: 32345.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8097 -0.5134 -0.1904  0.2435 22.6788
#
# Random effects:
#  Groups   Name                     Variance Std.Dev. Corr
#  userID   (Intercept)              0.578361 0.76050
#           distToHalfQuarter        0.007700 0.08775  -0.57
#           distToHorizontalVertical 0.007865 0.08868  -0.71  0.98
#           distToNearest5           0.084194 0.29016   0.04 -0.63 -0.55
#  Residual                          8.932529 2.98873
# Number of obs: 6400, groups:  userID, 40
#
# Fixed effects:
#                                         Estimate Std. Error         df t value
# (Intercept)                              0.27862    0.18360   71.19508   1.517
# chartTypepie                             1.39782    0.19609 6272.79526   7.128
# distToHalfQuarter                        0.15881    0.01996   64.89171   7.958
# distToHorizontalVertical                 0.22627    0.02323   60.05132   9.740
# distToNearest5                           0.15843    0.08457   87.50754   1.873
# chartTypepie:distToHalfQuarter          -0.04642    0.02028 6272.79527  -2.289
# chartTypepie:distToHorizontalVertical   -0.20206    0.02614 6272.79527  -7.731
# chartTypepie:distToNearest5              0.09861    0.10043 6272.79527   0.982
#                                       Pr(>|t|)
# (Intercept)                             0.1336
# chartTypepie                          1.13e-12 ***
# distToHalfQuarter                     3.51e-11 ***
# distToHorizontalVertical              5.69e-14 ***
# distToNearest5                          0.0643 .
# chartTypepie:distToHalfQuarter          0.0221 *
# chartTypepie:distToHorizontalVertical 1.24e-14 ***
# chartTypepie:distToNearest5             0.3262
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) chrtTy dstTHQ dstTHV dstTN5 cT:THQ cT:THV
# chartTypepi -0.534
# dstTHlfQrtr -0.611  0.327
# dstTHrzntlV -0.499  0.203  0.506
# distToNrst5 -0.324  0.318 -0.301 -0.201
# chrtTyp:THQ  0.343 -0.643 -0.508 -0.091  0.063
# chrtTyp:THV  0.193 -0.362 -0.082 -0.563  0.018  0.162
# chrtTyp:TN5  0.286 -0.535  0.054  0.017 -0.594 -0.107 -0.031
# optimizer (nloptwrap) convergence code: 0 (OK)
# boundary (singular) fit: see help('isSingular')

# %%
model <- lmer(
    absDiff ~ chartType * (distToHalfQuarter + distToHorizontalVertical + distToNearest5) + (1 | userID),
    data = data
)
summary(model)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: absDiff ~ chartType * (distToHalfQuarter + distToHorizontalVertical +
#     distToNearest5) + (1 | userID)
#    Data: data
#
# REML criterion at convergence: 32548.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.3298 -0.5171 -0.2211  0.2247 22.9445
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  userID   (Intercept) 0.2632   0.513
#  Residual             9.3208   3.053
# Number of obs: 6400, groups:  userID, 40
#
# Fixed effects:
#                                         Estimate Std. Error         df t value
# (Intercept)                              0.83504    0.16682  450.58582   5.006
# chartTypepie                             0.89427    0.20608 6353.00161   4.340
# distToHalfQuarter                        0.12949    0.01447 6353.02590   8.950
# distToHorizontalVertical                 0.01650    0.01597 6364.09076   1.034
# distToNearest5                           0.18244    0.07252 6353.00520   2.516
# chartTypepie:distToHalfQuarter          -0.02051    0.02046 6353.00161  -1.002
# chartTypepie:distToHorizontalVertical   -0.01154    0.02253 6353.00161  -0.512
# chartTypepie:distToNearest5              0.07368    0.10256 6353.00161   0.718
#                                       Pr(>|t|)
# (Intercept)                           8.00e-07 ***
# chartTypepie                          1.45e-05 ***
# distToHalfQuarter                      < 2e-16 ***
# distToHorizontalVertical                0.3014
# distToNearest5                          0.0119 *
# chartTypepie:distToHalfQuarter          0.3162
# chartTypepie:distToHorizontalVertical   0.6086
# chartTypepie:distToNearest5             0.4725
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) chrtTy dstTHQ dstTHV dstTN5 cT:THQ cT:THV
# chartTypepi -0.618
# dstTHlfQrtr -0.486  0.393
# dstTHrzntlV -0.370  0.298 -0.045
# distToNrst5 -0.470  0.381 -0.104  0.017
# chrtTyp:THQ  0.343 -0.556 -0.707  0.032  0.073
# chrtTyp:THV  0.261 -0.423  0.032 -0.706 -0.012 -0.045
# chrtTyp:TN5  0.333 -0.539  0.073 -0.012 -0.707 -0.104  0.017

# %%
model <- lmer(
    absDiff ~ chartType * (distToHalfQuarter + distToHorizontalVertical + distToNearest10) + (1 | userID),
    data = data
)
summary(model)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: absDiff ~ chartType * (distToHalfQuarter + distToHorizontalVertical +
#     distToNearest10) + (1 | userID)
#    Data: data
#
# REML criterion at convergence: 32562.3
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.2845 -0.5174 -0.2149  0.2310 22.9814
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  userID   (Intercept) 0.2631   0.5129
#  Residual             9.3371   3.0557
# Number of obs: 6400, groups:  userID, 40
#
# Fixed effects:
#                                         Estimate Std. Error         df t value
# (Intercept)                              0.91273    0.17028  486.92852   5.360
# chartTypepie                             0.88881    0.21167 6353.00160   4.199
# distToHalfQuarter                        0.13214    0.01442 6353.02460   9.161
# distToHorizontalVertical                 0.01596    0.01598 6364.10487   0.999
# distToNearest10                          0.05055    0.03607 6353.00215   1.402
# chartTypepie:distToHalfQuarter          -0.01978    0.02040 6353.00160  -0.970
# chartTypepie:distToHorizontalVertical   -0.01171    0.02255 6353.00160  -0.519
# chartTypepie:distToNearest10             0.03597    0.05101 6353.00160   0.705
#                                       Pr(>|t|)
# (Intercept)                           1.29e-07 ***
# chartTypepie                          2.72e-05 ***
# distToHalfQuarter                      < 2e-16 ***
# distToHorizontalVertical                 0.318
# distToNearest10                          0.161
# chartTypepie:distToHalfQuarter           0.332
# chartTypepie:distToHorizontalVertical    0.604
# chartTypepie:distToNearest10             0.481
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) chrtTy dstTHQ dstTHV dsTN10 cT:THQ cT:THV
# chartTypepi -0.622
# dstTHlfQrtr -0.498  0.401
# dstTHrzntlV -0.358  0.287 -0.044
# distTNrst10 -0.502  0.404 -0.056  0.007
# chrtTyp:THQ  0.352 -0.567 -0.707  0.031  0.039
# chrtTyp:THV  0.253 -0.407  0.031 -0.706 -0.005 -0.044
# chrtTy:TN10  0.355 -0.571  0.039 -0.005 -0.707 -0.056  0.007

# %%
pred_halfquarter <- ggpredict(model_interact, terms = c("distToHalfQuarter", "chartType"))
pred_horizvert   <- ggpredict(model_interact, terms = c("distToHorizontalVertical", "chartType"))
pred_nearest5    <- ggpredict(model_interact, terms = c("distToNearest5", "chartType"))

# Define a function for plotting
plot_pred <- function(pred_df, xlab_title) {
  ggplot(pred_df, aes(x = x, y = predicted, color = group)) +
    geom_line(size = 1.2) +
    geom_ribbon(aes(ymin = conf.low, ymax = conf.high, fill = group), alpha = 0.2, color = NA) +
    labs(x = xlab_title, y = "Predicted Error", color = "Chart Type", fill = "Chart Type") +
    theme_minimal(base_size = 14)
}

# Make the three plots
plot_halfquarter <- plot_pred(pred_halfquarter, "Distance to Half/Quarter")
plot_horizvert   <- plot_pred(pred_horizvert, "Distance to Horizontal/Vertical")
plot_nearest5    <- plot_pred(pred_nearest5, "Distance to Nearest 5")

plot_halfquarter / plot_horizvert / plot_nearest5
# Out:
# plot without title

# %%
model_interact <- lmer(
  absDiff ~ chartType * (distToHalfQuarter + distToHorizontalVertical + distToNearest5) + (1 | userID),
  data = data
)
model_no_interact <- lmer(
  absDiff ~ distToHalfQuarter + distToHorizontalVertical + distToNearest5 + chartType + (1 | userID),
  data = data
)

anova(model_no_interact, model_interact)
# Out:
# refitting model(s) with ML (instead of REML)
#                   npar AIC      BIC      logLik    -2*log(L) Chisq    Df
# model_no_interact  7   32524.83 32572.18 -16255.42 32510.83        NA NA
# model_interact    10   32529.13 32596.77 -16254.56 32509.13  1.707794  3
#                   Pr(>Chisq)
# model_no_interact        NA
# model_interact    0.6352023

# %%
pred_halfquarter <- ggpredict(model_interact, terms = c("distToHalfQuarter", "chartType"))
pred_horizvert   <- ggpredict(model_interact, terms = c("distToHorizontalVertical", "chartType"))
pred_nearest5    <- ggpredict(model_interact, terms = c("distToNearest5", "chartType"))

# Define a function for plotting
plot_pred <- function(pred_df, xlab_title) {
  ggplot(pred_df, aes(x = x, y = predicted, color = group)) +
    geom_line(size = 1.2) +
    geom_ribbon(aes(ymin = conf.low, ymax = conf.high, fill = group), alpha = 0.2, color = NA) +
    labs(x = xlab_title, y = "Predicted Error", color = "Chart Type", fill = "Chart Type") +
    theme_minimal(base_size = 14)
}

# Make the three plots
plot_halfquarter <- plot_pred(pred_halfquarter, "Distance to Half/Quarter")
plot_horizvert   <- plot_pred(pred_horizvert, "Distance to Horizontal/Vertical")
plot_nearest5    <- plot_pred(pred_nearest5, "Distance to Nearest 5")

plot_halfquarter / plot_horizvert / plot_nearest5
# Out:
# plot without title

# %%
model_mixed <- lmer(
  absDiff ~ chartType * (distToNearest5 + distToHalfQuarter * alignment) +
    (1 + distToNearest5 + distToHalfQuarter + alignment | userID),
  data = data,
  REML = FALSE  # for comparability and inference on fixed effects
)

summary(model_mixed)
# Out:
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# “Model failed to converge with max|grad| = 0.0650295 (tol = 0.002, component 1)”
# Linear mixed model fit by maximum likelihood . t-tests use Satterthwaite's
#   method [lmerModLmerTest]
# Formula:
# absDiff ~ chartType * (distToNearest5 + distToHalfQuarter * alignment) +
#     (1 + distToNearest5 + distToHalfQuarter + alignment | userID)
#    Data: data
#
#       AIC       BIC    logLik -2*log(L)  df.resid
#   32325.0   32467.0  -16141.5   32283.0      6379
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.8540 -0.5209 -0.1875  0.2533 22.6421
#
# Random effects:
#  Groups   Name                 Variance Std.Dev. Corr
#  userID   (Intercept)          0.721947 0.84967
#           distToNearest5       0.078918 0.28092  -0.08
#           distToHalfQuarter    0.006653 0.08157  -0.59 -0.53
#           alignmentnon-aligned 0.267994 0.51768  -0.83 -0.26  0.93
#  Residual                      8.880806 2.98007
# Number of obs: 6400, groups:  userID, 40
#
# Fixed effects:
#                                                       Estimate Std. Error
# (Intercept)                                          2.585e-01  2.135e-01
# chartTypepie                                         1.442e+00  2.346e-01
# distToNearest5                                       1.811e-01  8.356e-02
# distToHalfQuarter                                    1.249e-01  2.371e-02
# alignmentnon-aligned                                 1.281e+00  2.243e-01
# distToHalfQuarter:alignmentnon-aligned               1.059e-02  2.806e-02
# chartTypepie:distToNearest5                          7.459e-02  1.001e-01
# chartTypepie:distToHalfQuarter                      -1.964e-02  2.814e-02
# chartTypepie:alignmentnon-aligned                   -1.184e+00  2.953e-01
# chartTypepie:distToHalfQuarter:alignmentnon-aligned -2.667e-03  3.969e-02
#                                                             df t value Pr(>|t|)
# (Intercept)                                          1.077e+02   1.211   0.2286
# chartTypepie                                         6.279e+03   6.145 8.47e-10
# distToNearest5                                       9.740e+01   2.168   0.0326
# distToHalfQuarter                                    1.826e+02   5.266 3.90e-07
# alignmentnon-aligned                                 6.691e+02   5.710 1.70e-08
# distToHalfQuarter:alignmentnon-aligned               6.279e+03   0.377   0.7059
# chartTypepie:distToNearest5                          6.279e+03   0.745   0.4562
# chartTypepie:distToHalfQuarter                       6.279e+03  -0.698   0.4851
# chartTypepie:alignmentnon-aligned                    6.279e+03  -4.009 6.16e-05
# chartTypepie:distToHalfQuarter:alignmentnon-aligned  6.279e+03  -0.067   0.9464
#
# (Intercept)
# chartTypepie                                        ***
# distToNearest5                                      *
# distToHalfQuarter                                   ***
# alignmentnon-aligned                                ***
# distToHalfQuarter:alignmentnon-aligned
# chartTypepie:distToNearest5
# chartTypepie:distToHalfQuarter
# chartTypepie:alignmentnon-aligned                   ***
# chartTypepie:distToHalfQuarter:alignmentnon-aligned
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) chrtTy dstTN5 dstTHQ algnm- dTHQ:- cT:TN5 chT:THQ chrT:-
# chartTypepi -0.550
# distToNrst5 -0.327  0.273
# dstTHlfQrtr -0.680  0.435 -0.204
# algnmntnn-l -0.647  0.414 -0.051  0.661
# dstTHlfQr:-  0.422 -0.384  0.000 -0.592 -0.804
# chrtTyp:TN5  0.250 -0.456 -0.599  0.043  0.000  0.000
# chrtTyp:THQ  0.403 -0.733  0.044 -0.593 -0.401  0.499 -0.073
# chrtTypp:l-  0.346 -0.629  0.000 -0.361 -0.658  0.611  0.000  0.609
# chrtT:THQ:- -0.299  0.543  0.000  0.418  0.568 -0.707  0.000 -0.705  -0.863
# optimizer (nloptwrap) convergence code: 0 (OK)
# Model failed to converge with max|grad| = 0.0650295 (tol = 0.002, component 1)

# %%
model <- lmer(
  absDiff ~ chartType * (distToHalfQuarter * distToHorizontalVertical) +
    (1 | userID),
  data = data
)
summary(model)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula:
# absDiff ~ chartType * (distToHalfQuarter * distToHorizontalVertical) +
#     (1 | userID)
#    Data: data
#
# REML criterion at convergence: 32578.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.2707 -0.5227 -0.2103  0.2310 22.9752
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  userID   (Intercept) 0.2631   0.5129
#  Residual             9.3479   3.0574
# Number of obs: 6400, groups:  userID, 40
#
# Fixed effects:
#                                                           Estimate Std. Error
# (Intercept)                                              1.002e+00  1.736e-01
# chartTypepie                                             1.048e+00  2.170e-01
# distToHalfQuarter                                        1.383e-01  2.080e-02
# distToHorizontalVertical                                 2.406e-02  2.928e-02
# distToHalfQuarter:distToHorizontalVertical              -1.314e-03  3.907e-03
# chartTypepie:distToHalfQuarter                          -3.109e-02  2.938e-02
# chartTypepie:distToHorizontalVertical                   -3.163e-02  4.134e-02
# chartTypepie:distToHalfQuarter:distToHorizontalVertical  3.154e-03  5.515e-03
#                                                                 df t value
# (Intercept)                                              5.233e+02   5.768
# chartTypepie                                             6.353e+03   4.832
# distToHalfQuarter                                        6.358e+03   6.651
# distToHorizontalVertical                                 6.361e+03   0.822
# distToHalfQuarter:distToHorizontalVertical               6.363e+03  -0.336
# chartTypepie:distToHalfQuarter                           6.353e+03  -1.058
# chartTypepie:distToHorizontalVertical                    6.353e+03  -0.765
# chartTypepie:distToHalfQuarter:distToHorizontalVertical  6.353e+03   0.572
#                                                         Pr(>|t|)
# (Intercept)                                             1.37e-08 ***
# chartTypepie                                            1.39e-06 ***
# distToHalfQuarter                                       3.15e-11 ***
# distToHorizontalVertical                                   0.411
# distToHalfQuarter:distToHorizontalVertical                 0.737
# chartTypepie:distToHalfQuarter                             0.290
# chartTypepie:distToHorizontalVertical                      0.444
# chartTypepie:distToHalfQuarter:distToHorizontalVertical    0.567
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) chrtTy dstTHQ dstTHV dTHQ:T chT:THQ cT:THV
# chartTypepi -0.625
# dstTHlfQrtr -0.740  0.591
# dstTHrzntlV -0.633  0.505  0.588
# dstTHlQ:THV  0.529 -0.422 -0.721 -0.838
# chrtTyp:THQ  0.523 -0.837 -0.706 -0.415  0.508
# chrtTyp:THV  0.447 -0.716 -0.415 -0.706  0.591  0.587
# chT:THQ:THV -0.374  0.598  0.509  0.592 -0.706 -0.720  -0.838

# %%
model_pie <- lmer(
  absDiff ~ (distToHalfQuarter * distToHorizontalVertical) + (1 | userID),
  data = pieData
)
summary(model_pie)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: absDiff ~ (distToHalfQuarter * distToHorizontalVertical) + (1 |
#     userID)
#    Data: pieData
#
# REML criterion at convergence: 16488.4
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.5323 -0.5144 -0.1804  0.3260 22.1607
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  userID   (Intercept) 1.008    1.004
#  Residual             9.784    3.128
# Number of obs: 3200, groups:  userID, 40
#
# Fixed effects:
#                                              Estimate Std. Error         df
# (Intercept)                                 2.077e+00  2.234e-01  1.207e+02
# distToHalfQuarter                           1.041e-01  2.130e-02  3.160e+03
# distToHorizontalVertical                   -1.495e-02  3.001e-02  3.162e+03
# distToHalfQuarter:distToHorizontalVertical  2.683e-03  4.005e-03  3.163e+03
#                                            t value Pr(>|t|)
# (Intercept)                                  9.299 7.66e-16 ***
# distToHalfQuarter                            4.886 1.08e-06 ***
# distToHorizontalVertical                    -0.498    0.618
# distToHalfQuarter:distToHorizontalVertical   0.670    0.503
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) dstTHQ dstTHV
# dstTHlfQrtr -0.589
# dstTHrzntlV -0.505  0.588
# dstTHlQ:THV  0.421 -0.722 -0.838

# %%
model_line <- lmer(
  absDiff ~ (distToHalfQuarter * distToHorizontalVertical) + (1 | userID),
  data = lineData
)
summary(model_line)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: absDiff ~ (distToHalfQuarter * distToHorizontalVertical) + (1 |
#     userID)
#    Data: lineData
#
# REML criterion at convergence: 15904.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.1434 -0.4594 -0.2049  0.1661 16.6621
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  userID   (Intercept) 0.1703   0.4127
#  Residual             8.2760   2.8768
# Number of obs: 3200, groups:  userID, 40
#
# Fixed effects:
#                                              Estimate Std. Error         df
# (Intercept)                                 9.794e-01  1.586e-01  4.799e+02
# distToHalfQuarter                           1.408e-01  1.958e-02  3.167e+03
# distToHorizontalVertical                    2.997e-02  2.757e-02  3.173e+03
# distToHalfQuarter:distToHorizontalVertical -1.977e-03  3.680e-03  3.175e+03
#                                            t value Pr(>|t|)
# (Intercept)                                  6.176 1.40e-09 ***
# distToHalfQuarter                            7.192 7.95e-13 ***
# distToHorizontalVertical                     1.087    0.277
# distToHalfQuarter:distToHorizontalVertical  -0.537    0.591
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) dstTHQ dstTHV
# dstTHlfQrtr -0.762
# dstTHrzntlV -0.653  0.588
# dstTHlQ:THV  0.545 -0.721 -0.838

# %%
library(sjPlot)
plot_model(model_mixed, type = "re", sort.est = TRUE)
# Out:
# Sorting each group of random effects ('sort.all') is not possible when 'facets = TRUE'.
#
# Sorting each group of random effects ('sort.all') is not possible when 'facets = TRUE'.
#
# Sorting each group of random effects ('sort.all') is not possible when 'facets = TRUE'.
#
# Sorting each group of random effects ('sort.all') is not possible when 'facets = TRUE'.
# plot without title

# %%
model_mixed <- lmer(
  absDiff ~ chartType * (distToNearest5 + distToHalfQuarter * distToHorizontalVertical) +
    (distToNearest5 + distToHalfQuarter + distToHorizontalVertical | userID),
  data = data,
  REML = FALSE
)

summary(model_mixed)
# Out:
# boundary (singular) fit: see help('isSingular')
#
# Warning message:
# “Model failed to converge with 2 negative eigenvalues: -2.3e+00 -2.0e+03”
# Linear mixed model fit by maximum likelihood . t-tests use Satterthwaite's
#   method [lmerModLmerTest]
# Formula:
# absDiff ~ chartType * (distToNearest5 + distToHalfQuarter * distToHorizontalVertical) +
#     (distToNearest5 + distToHalfQuarter + distToHorizontalVertical |
#         userID)
#    Data: data
#
#       AIC       BIC    logLik -2*log(L)  df.resid
#   32537.2   32679.3  -16247.6   32495.2      6379
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.5619 -0.5142 -0.2436  0.2267 22.6164
#
# Random effects:
#  Groups   Name                     Variance  Std.Dev. Corr
#  userID   (Intercept)              0.0000000 0.00000
#           distToNearest5           0.1089519 0.33008    NaN
#           distToHalfQuarter        0.0046196 0.06797    NaN -0.56
#           distToHorizontalVertical 0.0006528 0.02555    NaN -0.69  0.99
#  Residual                          9.2406342 3.03984
# Number of obs: 6400, groups:  userID, 40
#
# Fixed effects:
#                                                           Estimate Std. Error
# (Intercept)                                              7.993e-01  1.692e-01
# chartTypepie                                             9.702e-01  2.391e-01
# distToNearest5                                           1.769e-01  8.920e-02
# distToHalfQuarter                                        1.355e-01  2.344e-02
# distToHorizontalVertical                                 2.662e-02  2.943e-02
# distToHalfQuarter:distToHorizontalVertical              -1.451e-03  3.899e-03
# chartTypepie:distToNearest5                              7.739e-02  1.023e-01
# chartTypepie:distToHalfQuarter                          -3.362e-02  2.940e-02
# chartTypepie:distToHorizontalVertical                   -3.287e-02  4.113e-02
# chartTypepie:distToHalfQuarter:distToHorizontalVertical  3.398e-03  5.493e-03
#                                                                 df t value
# (Intercept)                                              6.331e+03   4.724
# chartTypepie                                             6.318e+03   4.058
# distToNearest5                                           1.141e+02   1.983
# distToHalfQuarter                                        3.467e+02   5.781
# distToHorizontalVertical                                 3.254e+03   0.904
# distToHalfQuarter:distToHorizontalVertical               6.345e+03  -0.372
# chartTypepie:distToNearest5                              6.318e+03   0.757
# chartTypepie:distToHalfQuarter                           6.318e+03  -1.143
# chartTypepie:distToHorizontalVertical                    6.318e+03  -0.799
# chartTypepie:distToHalfQuarter:distToHorizontalVertical  6.318e+03   0.619
#                                                         Pr(>|t|)
# (Intercept)                                             2.36e-06 ***
# chartTypepie                                            5.01e-05 ***
# distToNearest5                                            0.0497 *
# distToHalfQuarter                                       1.66e-08 ***
# distToHorizontalVertical                                  0.3658
# distToHalfQuarter:distToHorizontalVertical                0.7098
# chartTypepie:distToNearest5                               0.4493
# chartTypepie:distToHalfQuarter                            0.2529
# chartTypepie:distToHorizontalVertical                     0.4243
# chartTypepie:distToHalfQuarter:distToHorizontalVertical   0.5362
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Correlation of Fixed Effects:
#             (Intr) chrtTy dstTN5 dstTHQ dstTHV dTHQ:T cT:TN5 chT:THQ cT:THV
# chartTypepi -0.707
# distToNrst5 -0.349  0.247
# dstTHlfQrtr -0.623  0.440 -0.234
# dstTHrzntlV -0.623  0.439 -0.088  0.580
# dstTHlQ:THV  0.513 -0.362  0.048 -0.642 -0.830
# chrtTyp:TN5  0.305 -0.431 -0.573  0.072  0.028 -0.041
# chrtTyp:THQ  0.495 -0.701  0.065 -0.627 -0.411  0.508 -0.114
# chrtTyp:THV  0.444 -0.628  0.023 -0.368 -0.699  0.590 -0.040  0.587
# chT:THQ:THV -0.363  0.513 -0.034  0.452  0.586 -0.704  0.059 -0.721  -0.838
# optimizer (nloptwrap) convergence code: 0 (OK)
# boundary (singular) fit: see help('isSingular')
