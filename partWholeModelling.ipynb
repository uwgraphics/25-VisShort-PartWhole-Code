# %%
library(ggplot2)
library(dplyr)
library(ggdist)
library(lme4)
library(ggeffects)
library(patchwork)
library(lmerTest)
library(brms)
library(blme)
library(rlang)
library(glmmTMB)
library(emmeans)

blue <- "#336199"
lightblue <- "#5688C7"
red <- "#E74236"
lightred <- "#EE766D"
green <- "#00A35F"
lightgreen <- "#0ACC7B"

# %%
# Load data
data <- read.csv("data/fullResults.csv", header=T)

data <- data %>%
  mutate(anchor = ifelse(anchorCategory == "anchor", "anchor", "non-anchor"))

data <- data %>%
  mutate(alignment = ifelse(alignmentCategory == "aligned", "aligned", "unaligned"))

data <- data %>%
  mutate(anchorType = case_when(
    selectedPart == 25 ~ "25",
    selectedPart == 50 ~ "50",
    TRUE ~ "non-anchor"
))

data$alignment <- factor(data$alignment, levels = c("aligned", "unaligned"))
data$anchor <- factor(data$anchor, levels = c("anchor", "non-anchor"))
data$chartType <- factor(data$chartType, levels = c("pie", "line"))

data$alignment_num <- ifelse(data$alignment == "aligned", -1, 1)
data$anchor_num <- ifelse(data$anchor == "anchor", -1, 1)
data$chartType_num <- ifelse(data$chartType == "pie", -1, 1)

data$alignmentCategory <- factor(data$alignmentCategory, levels = c("aligned", "near-aligned", "far-from-aligned"))
data$anchorCategory <- factor(data$anchorCategory, levels = c("anchor", "near-anchor", "far-anchor"))

data$distToNearest5 <- abs(data$selectedPart - round(data$selectedPart / 5) * 5) - 1

# data$distToNearest5 <- factor(data$distToNearest5, levels = c(0, 1, 2), ordered = TRUE)
# data$distToNearest5 <- ifelse(data$distToNearest5 == 0, "0", ifelse(data$distToNearest5 == 1, else "1", "2"))
data$distToNearest10 <- abs(data$selectedPart - round(data$selectedPart / 10) * 10) - 2

data
# Out:
#      responseTime prolificID               userID questionNum response
# 1     5.359       65847ecf0896ca006d2c00b7 2       0          30
# 2     3.518       65847ecf0896ca006d2c00b7 2       1          25
# 3     3.578       65847ecf0896ca006d2c00b7 2       2          22
# 4     6.439       65847ecf0896ca006d2c00b7 2       3          50
# 5     4.095       65847ecf0896ca006d2c00b7 2       4          40
# 6     5.763       65847ecf0896ca006d2c00b7 2       5          29
# 7     5.544       65847ecf0896ca006d2c00b7 2       6          26
# 8     4.659       65847ecf0896ca006d2c00b7 2       7          20
# 9     5.763       65847ecf0896ca006d2c00b7 2       8          45
# 10    3.669       65847ecf0896ca006d2c00b7 2       9          25
# 11    4.367       65847ecf0896ca006d2c00b7 2      10          29
# 12    5.404       65847ecf0896ca006d2c00b7 2      11          32
# 13    6.949       65847ecf0896ca006d2c00b7 2      12          45
# 14    7.613       65847ecf0896ca006d2c00b7 2      13          42
# 15    4.795       65847ecf0896ca006d2c00b7 2      14          23
# 16    5.184       65847ecf0896ca006d2c00b7 2      15          53
# 17    5.234       65847ecf0896ca006d2c00b7 2      16          23
# 18    4.808       65847ecf0896ca006d2c00b7 2      17          50
# 19   10.541       65847ecf0896ca006d2c00b7 2      18          37
# 20    5.379       65847ecf0896ca006d2c00b7 2      19          27
# 21    4.445       65847ecf0896ca006d2c00b7 2      20          24
# 22    6.290       65847ecf0896ca006d2c00b7 2      21          35
# 23    4.461       65847ecf0896ca006d2c00b7 2      22          25
# 24    4.004       65847ecf0896ca006d2c00b7 2      23          30
# 25    5.687       65847ecf0896ca006d2c00b7 2      24          37
# 26    3.928       65847ecf0896ca006d2c00b7 2      25          20
# 27    6.984       65847ecf0896ca006d2c00b7 2      26          43
# 28    6.990       65847ecf0896ca006d2c00b7 2      27          47
# 29    8.018       65847ecf0896ca006d2c00b7 2      28          26
# 30    7.535       65847ecf0896ca006d2c00b7 2      29          25
# ⋮    ⋮            ⋮                        ⋮      ⋮           ⋮
# 5583 12.699       67d3b49259e028491a5de44c 98     66          25
# 5584 12.984       67d3b49259e028491a5de44c 98     67          27
# 5585  8.972       67d3b49259e028491a5de44c 98     68          48
# 5586  9.788       67d3b49259e028491a5de44c 98     69          40
# 5587 13.807       67d3b49259e028491a5de44c 98     70          30
# 5588 10.570       67d3b49259e028491a5de44c 98     71          47
# 5589  8.472       67d3b49259e028491a5de44c 98     72          20
# 5590  9.649       67d3b49259e028491a5de44c 98     73          15
# 5591 11.162       67d3b49259e028491a5de44c 98     74          30
# 5592  9.803       67d3b49259e028491a5de44c 98     75          28
# 5593 11.391       67d3b49259e028491a5de44c 98     76          13
# 5594  7.876       67d3b49259e028491a5de44c 98     77          45
# 5595  8.124       67d3b49259e028491a5de44c 98     78          30
# 5596  9.197       67d3b49259e028491a5de44c 98     79          25
# 5597 14.765       67d3b49259e028491a5de44c 98     80          30
# 5598 10.572       67d3b49259e028491a5de44c 98     81          46
# 5599 12.743       67d3b49259e028491a5de44c 98     82          50
# 5600  8.589       67d3b49259e028491a5de44c 98     83          30
# 5601  9.714       67d3b49259e028491a5de44c 98     84          28
# 5602 14.159       67d3b49259e028491a5de44c 98     85          20
# 5603  7.672       67d3b49259e028491a5de44c 98     86          45
# 5604  8.635       67d3b49259e028491a5de44c 98     87          50
# 5605  5.581       67d3b49259e028491a5de44c 98     88          30
# 5606  6.318       67d3b49259e028491a5de44c 98     89          40
# 5607 10.868       67d3b49259e028491a5de44c 98     90          30
# 5608 10.835       67d3b49259e028491a5de44c 98     91          50
# 5609 10.616       67d3b49259e028491a5de44c 98     92          28
# 5610  5.420       67d3b49259e028491a5de44c 98     93          50
# 5611 10.311       67d3b49259e028491a5de44c 98     94          50
# 5612  8.190       67d3b49259e028491a5de44c 98     95          25
#      loadTime                questionID selectedPart alignmentCategory
# 1    2025-04-22 17:52:57.854  97        25           far-from-aligned
# 2    2025-04-22 17:53:03.377  98        25           aligned
# 3    2025-04-22 17:53:07.000  99        21           aligned
# 4    2025-04-22 17:53:10.687 100        46           far-from-aligned
# 5    2025-04-22 17:53:17.227 101        39           near-aligned
# 6    2025-04-22 17:53:21.422 102        32           near-aligned
# 7    2025-04-22 17:53:27.287 103        26           far-from-aligned
# 8    2025-04-22 17:53:32.935 104        21           aligned
# 9    2025-04-22 17:53:37.696 105        39           near-aligned
# 10   2025-04-22 17:53:43.562 106        25           near-aligned
# 11   2025-04-22 17:53:47.347 107        30           aligned
# 12   2025-04-22 17:53:51.816 108        34           near-aligned
# 13   2025-04-22 17:54:08.023 109        43           near-aligned
# 14   2025-04-22 17:54:15.076 110        51           far-from-aligned
# 15   2025-04-22 17:54:22.800 111        21           far-from-aligned
# 16   2025-04-22 17:54:27.698 112        54           near-aligned
# 17   2025-04-22 17:54:32.984 113        22           far-from-aligned
# 18   2025-04-22 17:54:38.318 114        49           near-aligned
# 19   2025-04-22 17:54:43.227 115        39           aligned
# 20   2025-04-22 17:54:53.870 116        27           aligned
# 21   2025-04-22 17:54:59.355 117        24           aligned
# 22   2025-04-22 17:55:03.906 118        39           far-from-aligned
# 23   2025-04-22 17:55:10.307 119        29           far-from-aligned
# 24   2025-04-22 17:55:14.868 120        30           near-aligned
# 25   2025-04-22 17:55:33.478 121        36           aligned
# 26   2025-04-22 17:55:39.266 122        18           aligned
# 27   2025-04-22 17:55:43.294 123        39           near-aligned
# 28   2025-04-22 17:55:50.390 124        47           far-from-aligned
# 29   2025-04-22 17:55:57.481 125        29           far-from-aligned
# 30   2025-04-22 17:56:05.614 126        31           far-from-aligned
# ⋮    ⋮                       ⋮          ⋮            ⋮
# 5583 2025-04-24 18:29:50.665 9379       25           aligned
# 5584 2025-04-24 18:30:03.675 9380       32           far-from-aligned
# 5585 2025-04-24 18:30:16.945 9381       49           aligned
# 5586 2025-04-24 18:30:26.229 9382       41           aligned
# 5587 2025-04-24 18:30:36.318 9383       34           aligned
# 5588 2025-04-24 18:30:50.422 9384       48           aligned
# 5589 2025-04-24 18:31:04.592 9385       23           aligned
# 5590 2025-04-24 18:31:13.363 9386       16           far-from-aligned
# 5591 2025-04-24 18:31:23.314 9387       30           far-from-aligned
# 5592 2025-04-24 18:31:34.776 9388       27           far-from-aligned
# 5593 2025-04-24 18:31:44.872 9389       16           aligned
# 5594 2025-04-24 18:31:56.563 9390       46           far-from-aligned
# 5595 2025-04-24 18:32:04.760 9391       29           far-from-aligned
# 5596 2025-04-24 18:32:13.176 9392       23           far-from-aligned
# 5597 2025-04-24 18:32:22.673 9393       33           far-from-aligned
# 5598 2025-04-24 18:32:37.742 9394       47           aligned
# 5599 2025-04-24 18:32:48.615 9395       50           near-aligned
# 5600 2025-04-24 18:33:01.677 9396       29           near-aligned
# 5601 2025-04-24 18:33:13.300 9397       27           far-from-aligned
# 5602 2025-04-24 18:33:23.300 9398       18           far-from-aligned
# 5603 2025-04-24 18:33:37.750 9399       46           near-aligned
# 5604 2025-04-24 18:33:45.734 9400       51           near-aligned
# 5605 2025-04-24 18:33:54.676 9401       29           aligned
# 5606 2025-04-24 18:34:01.101 9402       47           far-from-aligned
# 5607 2025-04-24 18:34:07.713 9403       32           far-from-aligned
# 5608 2025-04-24 18:34:18.870 9404       50           far-from-aligned
# 5609 2025-04-24 18:34:30.009 9405       28           near-aligned
# 5610 2025-04-24 18:34:40.935 9406       50           far-from-aligned
# 5611 2025-04-24 18:34:46.667 9407       50           near-aligned
# 5612 2025-04-24 18:34:57.285 9408       25           far-from-aligned
#      anchorCategory ⋯ excludedResponseError meanTime excludedTime
# 1    anchor         ⋯ includedResponse      5.23901  included
# 2    anchor         ⋯ includedResponse      5.23901  included
# 3    near-anchor    ⋯ includedResponse      5.23901  included
# 4    near-anchor    ⋯ includedResponse      5.23901  included
# 5    far-anchor     ⋯ includedResponse      5.23901  included
# 6    far-anchor     ⋯ includedResponse      5.23901  included
# 7    near-anchor    ⋯ includedResponse      5.23901  included
# 8    near-anchor    ⋯ includedResponse      5.23901  included
# 9    far-anchor     ⋯ includedResponse      5.23901  included
# 10   anchor         ⋯ includedResponse      5.23901  included
# 11   far-anchor     ⋯ includedResponse      5.23901  included
# 12   far-anchor     ⋯ includedResponse      5.23901  included
# 13   far-anchor     ⋯ includedResponse      5.23901  included
# 14   far-anchor     ⋯ includedResponse      5.23901  included
# 15   near-anchor    ⋯ includedResponse      5.23901  included
# 16   far-anchor     ⋯ includedResponse      5.23901  included
# 17   near-anchor    ⋯ includedResponse      5.23901  included
# 18   near-anchor    ⋯ includedResponse      5.23901  included
# 19   far-anchor     ⋯ includedResponse      5.23901  included
# 20   near-anchor    ⋯ includedResponse      5.23901  included
# 21   near-anchor    ⋯ includedResponse      5.23901  included
# 22   far-anchor     ⋯ includedResponse      5.23901  included
# 23   near-anchor    ⋯ includedResponse      5.23901  included
# 24   far-anchor     ⋯ includedResponse      5.23901  included
# 25   far-anchor     ⋯ includedResponse      5.23901  included
# 26   far-anchor     ⋯ includedResponse      5.23901  included
# 27   far-anchor     ⋯ includedResponse      5.23901  included
# 28   near-anchor    ⋯ includedResponse      5.23901  included
# 29   near-anchor    ⋯ includedResponse      5.23901  included
# 30   far-anchor     ⋯ includedResponse      5.23901  included
# ⋮    ⋮              ⋱ ⋮                     ⋮        ⋮
# 5583 anchor         ⋯ includedResponse      12.17418 included
# 5584 far-anchor     ⋯ includedResponse      12.17418 included
# 5585 near-anchor    ⋯ includedResponse      12.17418 included
# 5586 far-anchor     ⋯ includedResponse      12.17418 included
# 5587 far-anchor     ⋯ includedResponse      12.17418 included
# 5588 near-anchor    ⋯ includedResponse      12.17418 included
# 5589 near-anchor    ⋯ includedResponse      12.17418 included
# 5590 far-anchor     ⋯ includedResponse      12.17418 included
# 5591 far-anchor     ⋯ includedResponse      12.17418 included
# 5592 near-anchor    ⋯ includedResponse      12.17418 included
# 5593 far-anchor     ⋯ includedResponse      12.17418 included
# 5594 near-anchor    ⋯ includedResponse      12.17418 included
# 5595 near-anchor    ⋯ includedResponse      12.17418 included
# 5596 near-anchor    ⋯ includedResponse      12.17418 included
# 5597 far-anchor     ⋯ includedResponse      12.17418 included
# 5598 near-anchor    ⋯ includedResponse      12.17418 included
# 5599 anchor         ⋯ includedResponse      12.17418 included
# 5600 near-anchor    ⋯ includedResponse      12.17418 included
# 5601 near-anchor    ⋯ includedResponse      12.17418 included
# 5602 far-anchor     ⋯ includedResponse      12.17418 included
# 5603 near-anchor    ⋯ includedResponse      12.17418 included
# 5604 far-anchor     ⋯ includedResponse      12.17418 included
# 5605 near-anchor    ⋯ includedResponse      12.17418 included
# 5606 near-anchor    ⋯ includedResponse      12.17418 included
# 5607 far-anchor     ⋯ includedResponse      12.17418 included
# 5608 anchor         ⋯ includedResponse      12.17418 included
# 5609 near-anchor    ⋯ includedResponse      12.17418 included
# 5610 anchor         ⋯ includedResponse      12.17418 included
# 5611 anchor         ⋯ includedResponse      12.17418 included
# 5612 anchor         ⋯ includedResponse      12.17418 included
#      excludedResponseTime anchorType alignment_num anchor_num chartType_num
# 1    includedResponse     25          1            -1         -1
# 2    includedResponse     25         -1            -1          1
# 3    includedResponse     non-anchor -1             1          1
# 4    includedResponse     non-anchor  1             1          1
# 5    includedResponse     non-anchor  1             1          1
# 6    includedResponse     non-anchor  1             1          1
# 7    includedResponse     non-anchor  1             1         -1
# 8    includedResponse     non-anchor -1             1         -1
# 9    includedResponse     non-anchor  1             1          1
# 10   includedResponse     25          1            -1         -1
# 11   includedResponse     non-anchor -1             1         -1
# 12   includedResponse     non-anchor  1             1         -1
# 13   includedResponse     non-anchor  1             1         -1
# 14   includedResponse     non-anchor  1             1          1
# 15   includedResponse     non-anchor  1             1         -1
# 16   includedResponse     non-anchor  1             1         -1
# 17   includedResponse     non-anchor  1             1          1
# 18   includedResponse     non-anchor  1             1          1
# 19   includedResponse     non-anchor -1             1          1
# 20   includedResponse     non-anchor -1             1         -1
# 21   includedResponse     non-anchor -1             1          1
# 22   includedResponse     non-anchor  1             1         -1
# 23   includedResponse     non-anchor  1             1          1
# 24   includedResponse     non-anchor  1             1         -1
# 25   includedResponse     non-anchor -1             1          1
# 26   includedResponse     non-anchor -1             1         -1
# 27   includedResponse     non-anchor  1             1         -1
# 28   includedResponse     non-anchor  1             1         -1
# 29   includedResponse     non-anchor  1             1         -1
# 30   includedResponse     non-anchor  1             1          1
# ⋮    ⋮                    ⋮          ⋮             ⋮          ⋮
# 5583 includedResponse     25         -1            -1         -1
# 5584 includedResponse     non-anchor  1             1          1
# 5585 includedResponse     non-anchor -1             1         -1
# 5586 includedResponse     non-anchor -1             1         -1
# 5587 includedResponse     non-anchor -1             1          1
# 5588 includedResponse     non-anchor -1             1          1
# 5589 includedResponse     non-anchor -1             1         -1
# 5590 includedResponse     non-anchor  1             1          1
# 5591 includedResponse     non-anchor  1             1         -1
# 5592 includedResponse     non-anchor  1             1          1
# 5593 includedResponse     non-anchor -1             1          1
# 5594 includedResponse     non-anchor  1             1         -1
# 5595 includedResponse     non-anchor  1             1         -1
# 5596 includedResponse     non-anchor  1             1         -1
# 5597 includedResponse     non-anchor  1             1         -1
# 5598 includedResponse     non-anchor -1             1          1
# 5599 includedResponse     50          1            -1          1
# 5600 includedResponse     non-anchor  1             1         -1
# 5601 includedResponse     non-anchor  1             1          1
# 5602 includedResponse     non-anchor  1             1          1
# 5603 includedResponse     non-anchor  1             1          1
# 5604 includedResponse     non-anchor  1             1         -1
# 5605 includedResponse     non-anchor -1             1         -1
# 5606 includedResponse     non-anchor  1             1         -1
# 5607 includedResponse     non-anchor  1             1          1
# 5608 includedResponse     50          1            -1          1
# 5609 includedResponse     non-anchor  1             1          1
# 5610 includedResponse     50          1            -1         -1
# 5611 includedResponse     50          1            -1          1
# 5612 includedResponse     25          1            -1          1
#      distToNearest5 distToNearest10
# 1    -1              3
# 2    -1              3
# 3     0             -1
# 4     0              2
# 5     0             -1
# 6     1              0
# 7     0              2
# 8     0             -1
# 9     0             -1
# 10   -1              3
# 11   -1             -2
# 12    0              2
# 13    1              1
# 14    0             -1
# 15    0             -1
# 16    0              2
# 17    1              0
# 18    0             -1
# 19    0             -1
# 20    1              1
# 21    0              2
# 22    0             -1
# 23    0             -1
# 24   -1             -2
# 25    0              2
# 26    1              0
# 27    0             -1
# 28    1              1
# 29    0             -1
# 30    0             -1
# ⋮    ⋮              ⋮
# 5583 -1              3
# 5584  1              0
# 5585  0             -1
# 5586  0             -1
# 5587  0              2
# 5588  1              0
# 5589  1              1
# 5590  0              2
# 5591 -1             -2
# 5592  1              1
# 5593  0              2
# 5594  0              2
# 5595  0             -1
# 5596  1              1
# 5597  1              1
# 5598  1              1
# 5599 -1             -2
# 5600  0             -1
# 5601  1              1
# 5602  1              0
# 5603  0              2
# 5604  0             -1
# 5605  0             -1
# 5606  1              1
# 5607  1              0
# 5608 -1             -2
# 5609  1              0
# 5610 -1             -2
# 5611 -1             -2
# 5612 -1              3

# %%
# --- Build Model --------------------------------------------------------------
model <- glmmTMB(
  absError ~ chartType_num * anchor_num * alignment_num +
    (1 + anchor_num + alignment_num + chartType_num | userID),
  data = data,
  family = nbinom2(link = "log")
)

# %%
make_predictor_plot <- function(model, predictor, title_label) {
  library(ggeffects)
  library(ggplot2)
  library(dplyr)
  library(rlang)
  library(ggdist)

  mf <- model.frame(model)

  newdata <- mf %>%
    select(userID, chartType, anchor, alignment, distToNearest5) %>%
    distinct()

  newdata$predicted <- predict(model, newdata = newdata, re.form = NULL)

  avg_pred <- ggpredict(model, terms = c(predictor, "chartType"))
  avg_pred_df <- as.data.frame(avg_pred)

  is_categorical <- !is.numeric(avg_pred_df$x)

  if (is_categorical) {
    avg_pred_df$x <- factor(avg_pred_df$x, levels = unique(avg_pred_df$x))
    newdata[[predictor]] <- factor(newdata[[predictor]], levels = unique(avg_pred_df$x))
  }

  ggplot() +
    stat_gradientinterval(
      data = avg_pred_df,
      fill_type = "gradient",
      aes(x = x, y = predicted, ymin = conf.low, ymax = conf.high, group = group, color = group, fill = group),
      point_size = 3,
      show.legend = FALSE,
      inherit.aes = FALSE,
      position = position_dodge(width = 0.5) # Separate the chartTypes a bit
    ) +
    scale_color_manual(values = c(
      "line" = green,   # replace with your color variables
      "pie" = red
    )) +
    scale_fill_manual(values = c(
      "line" = lightgreen,
      "pie" = lightred
    )) +
    labs(
      title = title_label,
      x = predictor,
      y = "Predicted AbsDiff"
    ) +
    theme_minimal(base_size = 14)
}

# %%
model_poisson <- glmmTMB(
  absError ~ chartType_num * anchor_num * alignment_num +
    (1 + anchor_num + alignment_num + chartType_num | userID),
  data = data,
  family = poisson(link = "log")
)

model_nb <- glmmTMB(
  absError ~ chartType_num * anchor_num * alignment_num +
    (1 + anchor_num + alignment_num + chartType_num | userID),
  data = data,
  family = nbinom2(link = "log")
)
model_tweedie <- glmmTMB(
  absError ~ chartType_num * anchor_num * alignment_num +
    (1 + anchor_num + alignment_num + chartType_num | userID),
  data = data,
  family = tweedie(link = "log")
)
AIC(model_poisson, model_nb, model_tweedie)
anova(model_nb, model_poisson, model_tweedie)
# Out:
#               df AIC
# model_poisson 18 26251.76
# model_nb      19 23202.92
# model_tweedie 20 23580.43
#               Df AIC      BIC      logLik    deviance Chisq    Chi Df
# model_poisson 18 26251.76 26371.15 -13107.88 26215.76       NA NA
# model_nb      19 23202.92 23328.94 -11582.46 23164.92 3050.841  1
# model_tweedie 20 23580.43 23713.08 -11770.22 23540.43    0.000  1
#               Pr(>Chisq)
# model_poisson NA
# model_nb       0
# model_tweedie  1

# %%
model <- glmmTMB(
  absError ~ chartType_num * anchor_num * alignment_num +
    (1 + anchor_num + alignment_num + chartType_num | userID),
  data = data,
  family = nbinom2(link = "log")
)

modelRound5 <- glmmTMB(
  absError ~ chartType_num * anchor_num * alignment_num + distToNearest5 +
    (1 + anchor_num + alignment_num + chartType_num + distToNearest5 | userID),
  data = data,
  family = nbinom2(link = "log")
)

modelRound10 <- glmmTMB(
  absError ~ chartType_num * anchor_num * alignment_num + distToNearest10 +
    (1 + anchor_num + alignment_num + chartType_num + distToNearest10 | userID),
  data = data,
  family = nbinom2(link = "log")
)
# Out:
# Warning message in finalizeTMB(TMBStruc, obj, fit, h, data.tmb.old):
# “Model convergence problem; singular convergence (7). See vignette('troubleshooting'), help('diagnose')”

# %%
anova(model, modelRound5, modelRound10)
# --- Model Summary ------------------------------------------------------------
summary(model)
summary(modelRound5)
summary(modelRound10)
# Out:
#              Df AIC      BIC      logLik    deviance Chisq    Chi Df Pr(>Chisq)
# model        19 23202.92 23328.94 -11582.46 23164.92       NA NA            NA
# modelRound5  25 23205.67 23371.49 -11577.84 23155.67 9.252264  6     0.1598801
# modelRound10 25 23198.32 23364.13 -11574.16 23148.32 7.354825  0     0.0000000
#  Family: nbinom2  ( log )
# Formula:          absError ~ chartType_num * anchor_num * alignment_num + (1 +
#     anchor_num + alignment_num + chartType_num | userID)
# Data: data
#
#       AIC       BIC    logLik -2*log(L)  df.resid
#   23202.9   23328.9  -11582.5   23164.9      5593
#
# Random effects:
#
# Conditional model:
#  Groups Name          Variance Std.Dev. Corr
#  userID (Intercept)   0.49225  0.7016
#         anchor_num    0.13723  0.3704   -0.92
#         alignment_num 0.01488  0.1220   -0.69  0.52
#         chartType_num 0.01849  0.1360    0.18 -0.19 -0.35
# Number of obs: 5612, groups:  userID, 60
#
# Dispersion parameter for nbinom2 family (): 1.89
#
# Conditional model:
#                                         Estimate Std. Error z value Pr(>|z|)
# (Intercept)                             0.266751   0.097208   2.744  0.00607
# chartType_num                           0.041128   0.034461   1.193  0.23269
# anchor_num                              0.643684   0.059232  10.867  < 2e-16
# alignment_num                           0.359225   0.034419  10.437  < 2e-16
# chartType_num:anchor_num                0.011710   0.029367   0.399  0.69009
# chartType_num:alignment_num             0.006722   0.029005   0.232  0.81672
# anchor_num:alignment_num               -0.171386   0.030082  -5.697 1.22e-08
# chartType_num:anchor_num:alignment_num  0.020705   0.028867   0.717  0.47321
#
# (Intercept)                            **
# chartType_num
# anchor_num                             ***
# alignment_num                          ***
# chartType_num:anchor_num
# chartType_num:alignment_num
# anchor_num:alignment_num               ***
# chartType_num:anchor_num:alignment_num
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#  Family: nbinom2  ( log )
# Formula:
# absError ~ chartType_num * anchor_num * alignment_num + distToNearest5 +
#     (1 + anchor_num + alignment_num + chartType_num + distToNearest5 |
#         userID)
# Data: data
#
#       AIC       BIC    logLik -2*log(L)  df.resid
#   23205.7   23371.5  -11577.8   23155.7      5587
#
# Random effects:
#
# Conditional model:
#  Groups Name           Variance Std.Dev. Corr
#  userID (Intercept)    0.514274 0.71713
#         anchor_num     0.165839 0.40723  -0.92
#         alignment_num  0.015025 0.12257  -0.68  0.49
#         chartType_num  0.018600 0.13638   0.20 -0.23 -0.35
#         distToNearest5 0.005203 0.07213   0.66 -0.89 -0.20  0.40
# Number of obs: 5612, groups:  userID, 60
#
# Dispersion parameter for nbinom2 family ():  1.9
#
# Conditional model:
#                                         Estimate Std. Error z value Pr(>|z|)
# (Intercept)                             0.269741   0.099262   2.717  0.00658
# chartType_num                           0.040779   0.034441   1.184  0.23641
# anchor_num                              0.636336   0.064270   9.901  < 2e-16
# alignment_num                           0.359463   0.034412  10.446  < 2e-16
# distToNearest5                          0.007787   0.021571   0.361  0.71810
# chartType_num:anchor_num                0.011541   0.029309   0.394  0.69374
# chartType_num:alignment_num             0.006361   0.028951   0.220  0.82610
# anchor_num:alignment_num               -0.170972   0.030047  -5.690 1.27e-08
# chartType_num:anchor_num:alignment_num  0.020592   0.028811   0.715  0.47478
#
# (Intercept)                            **
# chartType_num
# anchor_num                             ***
# alignment_num                          ***
# distToNearest5
# chartType_num:anchor_num
# chartType_num:alignment_num
# anchor_num:alignment_num               ***
# chartType_num:anchor_num:alignment_num
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#  Family: nbinom2  ( log )
# Formula:
# absError ~ chartType_num * anchor_num * alignment_num + distToNearest10 +
#     (1 + anchor_num + alignment_num + chartType_num + distToNearest10 |
#         userID)
# Data: data
#
#       AIC       BIC    logLik -2*log(L)  df.resid
#   23198.3   23364.1  -11574.2   23148.3      5587
#
# Random effects:
#
# Conditional model:
#  Groups Name            Variance Std.Dev. Corr
#  userID (Intercept)     0.498816 0.70627
#         anchor_num      0.137221 0.37043  -0.93
#         alignment_num   0.015398 0.12409  -0.66  0.50
#         chartType_num   0.018665 0.13662   0.18 -0.20 -0.36
#         distToNearest10 0.002904 0.05389  -0.14  0.20 -0.32 -0.01
# Number of obs: 5612, groups:  userID, 60
#
# Dispersion parameter for nbinom2 family (): 1.91
#
# Conditional model:
#                                         Estimate Std. Error z value Pr(>|z|)
# (Intercept)                             0.237486   0.098208   2.418   0.0156
# chartType_num                           0.036388   0.034640   1.050   0.2935
# anchor_num                              0.656509   0.059412  11.050  < 2e-16
# alignment_num                           0.361369   0.034666  10.424  < 2e-16
# distToNearest10                         0.023832   0.011303   2.108   0.0350
# chartType_num:anchor_num                0.018127   0.029553   0.613   0.5396
# chartType_num:alignment_num             0.004644   0.029090   0.160   0.8732
# anchor_num:alignment_num               -0.173381   0.030207  -5.740 9.48e-09
# chartType_num:anchor_num:alignment_num  0.022538   0.028964   0.778   0.4365
#
# (Intercept)                            *
# chartType_num
# anchor_num                             ***
# alignment_num                          ***
# distToNearest10                        *
# chartType_num:anchor_num
# chartType_num:alignment_num
# anchor_num:alignment_num               ***
# chartType_num:anchor_num:alignment_num
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
modelResponseTime <- glmmTMB(
  responseTime ~ chartType_num * anchor_num * alignment_num +
    (1 + anchor_num + alignment_num + chartType_num | userID),
  data = data,
  family = Gamma(link = "log")
)
summary(modelResponseTime)
# Out:
#  Family: Gamma  ( log )
# Formula:
# responseTime ~ chartType_num * anchor_num * alignment_num + (1 +
#     anchor_num + alignment_num + chartType_num | userID)
# Data: data
#
#       AIC       BIC    logLik -2*log(L)  df.resid
#   27055.1   27181.1  -13508.5   27017.1      5593
#
# Random effects:
#
# Conditional model:
#  Groups Name          Variance  Std.Dev. Corr
#  userID (Intercept)   0.1248288 0.35331
#         anchor_num    0.0019921 0.04463   0.12
#         alignment_num 0.0007469 0.02733   0.31 -0.44
#         chartType_num 0.0033118 0.05755   0.16  0.35  0.04
# Number of obs: 5612, groups:  userID, 60
#
# Dispersion estimate for Gamma family (sigma^2): 0.147
#
# Conditional model:
#                                          Estimate Std. Error z value Pr(>|z|)
# (Intercept)                             1.8728939  0.0463525   40.41  < 2e-16
# chartType_num                           0.0008645  0.0110938    0.08  0.93788
# anchor_num                              0.1137857  0.0100649   11.31  < 2e-16
# alignment_num                           0.0447381  0.0089718    4.99 6.15e-07
# chartType_num:anchor_num                0.0022411  0.0082407    0.27  0.78566
# chartType_num:alignment_num             0.0076082  0.0082410    0.92  0.35589
# anchor_num:alignment_num               -0.0234473  0.0082497   -2.84  0.00448
# chartType_num:anchor_num:alignment_num -0.0107225  0.0082441   -1.30  0.19339
#
# (Intercept)                            ***
# chartType_num
# anchor_num                             ***
# alignment_num                          ***
# chartType_num:anchor_num
# chartType_num:alignment_num
# anchor_num:alignment_num               **
# chartType_num:anchor_num:alignment_num
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# # Get model predictions
# preds <- emmeans(model_poisson, ~ alignment_num * anchor_num * chartType_num)
# preds_df <- as.data.frame(preds)
#
# # Filter predicted aligned-anchor-pie
# preds_aligned_anchor <- preds_df %>%
#   filter(alignment_num == -1, anchor_num == -1, chartType_num == -1)
#
# # Filter raw data aligned-anchor-pie
# data_aligned_anchor <- data %>%
#   filter(chartType == "pie", alignment == "aligned", anchor == "anchor")
#
# # Plot
# ggplot(data_aligned_anchor, aes(x = responseTime)) +
#   stat_halfeye(
#     slab_alpha = 0.5,
#     point_size = 3,
#     point_alpha = 0.8,
#     color = "darkgreen",
#     fill = "lightgreen",
#     point_interval = mean_hdci,
#     .width = 1
#   ) +
#   geom_pointrange(
#     data = preds_aligned_anchor,
#     aes(x = emmean, xmin = lower.CL, xmax = upper.CL, y = 0),
#     color = "blue",
#     size = 1.2,
#     inherit.aes = FALSE
#   ) +
#   theme_minimal(base_size = 16) +
#   coord_cartesian(xlim = c(0, max(data_aligned_anchor$responseTime) * 1.05)) +
#   labs(
#     title = "Observed Distribution and Predicted Mean+CI (Aligned Anchor)",
#     x = "Response Time (s)",
#     y = NULL
#   )

# %%
# Function to compute overdispersion statistic
check_overdispersion <- function(model) {
  # Pearson residuals
  resids <- residuals(model, type = "pearson")
  
  # Degrees of freedom
  df_resid <- nrow(model.frame(model)) - length(fixef(model)$cond)
  
  # Dispersion ratio
  dispersion <- sum(resids^2) / df_resid
  
  return(dispersion)
}

# Run it
dispersion_value <- check_overdispersion(modelRound)
dispersion_value
# Out:
# Error: object 'modelRound' not found
# Traceback:
#
# 1. residuals(model, type = "pearson")
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'modelRound' not found", base::quote(eval(expr, envir)))

# %%
modelRound <- glmmTMB(
  absError ~ chartType * anchor * alignment + distToNearest5 +
    (1 + anchor + alignment + chartType || userID),
  data = data,
  family = poisson(link = "log")
)

summary(modelRound)
# Out:
#  Family: poisson  ( log )
# Formula:          absError ~ chartType * anchor * alignment + distToNearest5 +
#     (1 + anchor + alignment + chartType || userID)
# Data: data
#
#       AIC       BIC    logLik -2*log(L)  df.resid
#   26347.8   26434.1  -13160.9   26321.8      5599
#
# Random effects:
#
# Conditional model:
#  Groups Name        Variance Std.Dev. Corr
#  userID (Intercept) 0.37022  0.6085
#         anchor      0.10662  0.3265   0.00
#         alignment   0.01938  0.1392   0.00 0.00
#         chartType   0.02257  0.1502   0.00 0.00 0.00
# Number of obs: 5612, groups:  userID, 60
#
# Conditional model:
#                             Estimate Std. Error z value Pr(>|z|)
# (Intercept)                 0.338782   0.083444   4.060 4.91e-05 ***
# chartType                   0.049939   0.028413   1.758   0.0788 .
# anchor                      0.548126   0.050448  10.865  < 2e-16 ***
# alignment                   0.293550   0.027758  10.575  < 2e-16 ***
# distToNearest5              0.009307   0.011827   0.787   0.4313
# chartType:anchor            0.005164   0.020373   0.253   0.7999
# chartType:alignment         0.012536   0.020175   0.621   0.5344
# anchor:alignment           -0.108227   0.020355  -5.317 1.06e-07 ***
# chartType:anchor:alignment  0.012797   0.020092   0.637   0.5242
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
em_anchor_alignment <- emmeans(modelRound, ~ anchor * alignment)
summary(em_anchor_alignment)

plot_anchor_alignment <- as.data.frame(em_anchor_alignment) %>%
  mutate(
    predicted = exp(emmean),
    anchor = ifelse(anchor == -1, "Anchor", "Non-Anchor"),
    alignment = ifelse(alignment == -1, "Aligned", "Unaligned")
  ) %>%
  ggplot(aes(x = alignment, y = predicted, group = anchor, color = anchor)) +
  geom_line(linewidth = 1.2) +
  geom_point(size = 3) +
  geom_errorbar(aes(ymin = exp(asymp.LCL), ymax = exp(asymp.UCL)), width = 0.2) +
  coord_cartesian(ylim = c(0, NA)) +
  theme_minimal(base_size = 16) +   # no printing
  labs(
    title = "Interaction of Anchoring and Alignment",
    x = "Alignment",
    y = "Predicted Mean Absolute Error",
    color = "Anchor"
  )
plot_anchor_alignment
# Out:
# NOTE: Results may be misleading due to involvement in interactions
#   anchor alignment emmean     SE         df  asymp.LCL     asymp.UCL
# 1 -1     -1        -0.6008443 0.12179914 Inf -0.8395662463 -0.3621224
# 2  1     -1         0.7118616 0.09323325 Inf  0.5291277844  0.8945954
# 3 -1      1         0.2027092 0.10372361 Inf -0.0005853716  0.4060037
# 4  1      1         1.0825084 0.09150367 Inf  0.9031645161  1.2618523
# plot without title

# %%
model <- glmmTMB(
  absError ~ anchor * alignment * chartType + 
  distToNearest5 + distToNearest5:alignment +
    (1 + anchor + alignment + chartType | userID),
  data = data,
  family = poisson(link = "log")
)

summary(model)
# Out:
#  Family: poisson  ( log )
# Formula:          absError ~ anchor * alignment * chartType + distToNearest5 +
#     distToNearest5:alignment + (1 + anchor + alignment + chartType |
#     userID)
# Data: data
#
#       AIC       BIC    logLik -2*log(L)  df.resid
#   26240.8   26373.5  -13100.4   26200.8      5592
#
# Random effects:
#
# Conditional model:
#  Groups Name        Variance Std.Dev. Corr
#  userID (Intercept) 0.48509  0.6965
#         anchor      0.14391  0.3794   -0.90
#         alignment   0.02043  0.1429   -0.55  0.33
#         chartType   0.02251  0.1500    0.14 -0.14 -0.25
# Number of obs: 5612, groups:  userID, 60
#
# Conditional model:
#                            Estimate Std. Error z value Pr(>|z|)
# (Intercept)                 0.25808    0.09499   2.717 0.006590 **
# anchor                      0.57867    0.05754  10.057  < 2e-16 ***
# alignment                   0.34623    0.03005  11.522  < 2e-16 ***
# chartType                   0.04657    0.02856   1.630 0.103059
# distToNearest5              0.04609    0.01527   3.018 0.002547 **
# anchor:alignment           -0.07743    0.02286  -3.387 0.000707 ***
# anchor:chartType            0.00735    0.02046   0.359 0.719471
# alignment:chartType         0.01432    0.02021   0.709 0.478480
# alignment:distToNearest5   -0.05733    0.01529  -3.750 0.000177 ***
# anchor:alignment:chartType  0.01211    0.02009   0.603 0.546602
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
options(repr.plot.width = 8, repr.plot.height = 8)

plot_anchor <- make_predictor_plot(model, "anchor", "Effect of Anchoring")
plot_alignment <- make_predictor_plot(model, "alignment", "Effect of Alignment")
plot_chartType <- make_predictor_plot(model, "chartType", "Effect of Chart Type")

# %%
plot_anchor + plot_alignment + plot_layout(guides="collect", axes="collect")
# Out:
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's fill values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's fill values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's fill values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's colour values.”
# Warning message:
# “No shared levels found between `names(values)` of the manual scale and the
# data's fill values.”
# plot without title

# %%
head(data)
# Out:
#   responseTime prolificID               userID questionNum response
# 1 5.359        65847ecf0896ca006d2c00b7 2      0           30
# 2 3.518        65847ecf0896ca006d2c00b7 2      1           25
# 3 3.578        65847ecf0896ca006d2c00b7 2      2           22
# 4 6.439        65847ecf0896ca006d2c00b7 2      3           50
# 5 4.095        65847ecf0896ca006d2c00b7 2      4           40
# 6 5.763        65847ecf0896ca006d2c00b7 2      5           29
#   loadTime                questionID selectedPart alignmentCategory
# 1 2025-04-22 17:52:57.854  97        25           far-from-aligned
# 2 2025-04-22 17:53:03.377  98        25           aligned
# 3 2025-04-22 17:53:07.000  99        21           aligned
# 4 2025-04-22 17:53:10.687 100        46           far-from-aligned
# 5 2025-04-22 17:53:17.227 101        39           near-aligned
# 6 2025-04-22 17:53:21.422 102        32           near-aligned
#   anchorCategory ⋯ anchor alignment meanError excludedError
# 1 anchor         ⋯ -1      1        2.28125   included
# 2 anchor         ⋯ -1     -1        2.28125   included
# 3 near-anchor    ⋯  1     -1        2.28125   included
# 4 near-anchor    ⋯  1      1        2.28125   included
# 5 far-anchor     ⋯  1      1        2.28125   included
# 6 far-anchor     ⋯  1      1        2.28125   included
#   excludedResponseError meanTime excludedTime excludedResponseTime anchorType
# 1 includedResponse      5.23901  included     includedResponse     25
# 2 includedResponse      5.23901  included     includedResponse     25
# 3 includedResponse      5.23901  included     includedResponse     non-anchor
# 4 includedResponse      5.23901  included     includedResponse     non-anchor
# 5 includedResponse      5.23901  included     includedResponse     non-anchor
# 6 includedResponse      5.23901  included     includedResponse     non-anchor
#   distToNearest5
# 1 0
# 2 0
# 3 1
# 4 1
# 5 1
# 6 2

# %%
ggplot(data, aes(x = alignment, y = absError, group = chartType, slab_color=chartType)) +
  stat_gradientinterval(
    fill_type = "gradient"
      ) +
  theme_minimal(base_size = 14)
# Out:
# plot without title
